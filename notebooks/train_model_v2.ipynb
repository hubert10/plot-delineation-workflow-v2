# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd  '/content/drive/My Drive/PROJECTS/HABITUS/plot-delineation-workflow-v2'
# Out:
# /content/drive/My Drive/PROJECTS/HABITUS/plot-delineation-workflow-v2

# %%
"""
In this section, the required changes to the Mask R-CNN project are discussed so that it fully supports TensorFlow 2.0 
for making predictions (i.e. when the mode parameter in the mrcnn.model.MaskRCNN class constructor is set to inference).
In a later section, more edits are applied to train the Mask R-CNN model in TensorFlow 2.0 (i.e. when the mode parameter
in the mrcnn.model.MaskRCNN class constructor is set to training).

"""

import json
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf


# Set this to True to see more logs details
os.environ["AUTOGRAPH_VERBOSITY"] = "5"
tf.autograph.set_verbosity(3, False)
tf.cast
import warnings

warnings.filterwarnings("ignore")
# from utils.config import CustomConfig


# tf.compat.v1.disable_eager_execution()


# Buiproject_pathld paths inside the project like this: os.path.join(BASE_DIR, ...)
BASE_DIR = '/content/drive/My Drive/PROJECTS/HABITUS/plot-delineation-workflow-v2' #os.path.dirname(os.path.abspath('__file__'))
PROJECT_ROOT = BASE_DIR + "/"
print(PROJECT_ROOT)
# Out:
# /content/drive/My Drive/PROJECTS/HABITUS/plot-delineation-workflow-v2/
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: beautifulsoup4==4.8.2 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 1)) (4.8.2)
# Requirement already satisfied: black==22.1.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 2)) (22.1.0)
# Requirement already satisfied: cmake==3.22.2 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 3)) (3.22.2)
# Requirement already satisfied: distro==1.7.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 4)) (1.7.0)
# Requirement already satisfied: Fiona==1.8.21 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 5)) (1.8.21)
# Requirement already satisfied: flatbuffers==1.12 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 6)) (1.12)
# Requirement already satisfied: fonttools==4.29.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 7)) (4.29.0)
# Requirement already satisfied: future==0.18.2 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 8)) (0.18.2)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 9)) (0.3.3)
# Requirement already satisfied: geopandas==0.10.2 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 10)) (0.10.2)
# Requirement already satisfied: grpcio==1.34.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 11)) (1.34.1)
# Requirement already satisfied: h5py==2.10.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 12)) (2.10.0)
# Requirement already satisfied: html5lib==1.0.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 13)) (1.0.1)
# Requirement already satisfied: httplib2==0.14.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 14)) (0.14.0)
# Requirement already satisfied: idna==3.3 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 15)) (3.3)
# Requirement already satisfied: imageio==2.14.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 16)) (2.14.1)
# Requirement already satisfied: importlib-metadata==4.10.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 17)) (4.10.1)
# Requirement already satisfied: importlib-resources==5.4.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 18)) (5.4.0)
# Requirement already satisfied: ipykernel==6.9.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 19)) (6.9.0)
# Requirement already satisfied: itsdangerous==2.0.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 20)) (2.0.1)
# Requirement already satisfied: Jinja2==3.0.3 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 21)) (3.0.3)
# Requirement already satisfied: joblib==1.1.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 22)) (1.1.0)
# Requirement already satisfied: jupyter==1.0.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 23)) (1.0.0)
# Requirement already satisfied: jupyter-client==7.1.2 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 24)) (7.1.2)
# Requirement already satisfied: jupyter-console==6.4.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 25)) (6.4.0)
# Requirement already satisfied: jupyter-core==4.9.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 26)) (4.9.1)
# Requirement already satisfied: jupyterlab-pygments==0.1.2 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 27)) (0.1.2)
# Requirement already satisfied: jupyterlab-widgets==1.0.2 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 28)) (1.0.2)
# Requirement already satisfied: Keras==2.3.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 29)) (2.3.1)
# Requirement already satisfied: Keras-Applications==1.0.8 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 30)) (1.0.8)
# Requirement already satisfied: Keras-Preprocessing==1.1.2 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 31)) (1.1.2)
# Requirement already satisfied: macaroonbakery==1.3.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 32)) (1.3.1)
# Requirement already satisfied: Markdown==3.3.6 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 33)) (3.3.6)
# Requirement already satisfied: MarkupSafe==2.0.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 34)) (2.0.1)
# Requirement already satisfied: matplotlib==3.5.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 35)) (3.5.1)
# Requirement already satisfied: matplotlib-inline==0.1.3 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 36)) (0.1.3)
# Requirement already satisfied: networkx==2.6.3 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 37)) (2.6.3)
# Requirement already satisfied: notebook==6.4.8 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 38)) (6.4.8)
# Requirement already satisfied: numba==0.55.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 39)) (0.55.1)
# Requirement already satisfied: numpy==1.19.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 40)) (1.19.0)
# Requirement already satisfied: oauthlib==3.2.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 41)) (3.2.0)
# Requirement already satisfied: olefile==0.46 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 42)) (0.46)
# Requirement already satisfied: opencv-contrib-python==4.6.0.66 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 43)) (4.6.0.66)
# Requirement already satisfied: opencv-python==4.6.0.66 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 44)) (4.6.0.66)
# Requirement already satisfied: p5py==1.0.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 45)) (1.0.0)
# Requirement already satisfied: pandas==1.3.5 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 46)) (1.3.5)
# Requirement already satisfied: Pillow==9.0.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 47)) (9.0.0)
# Requirement already satisfied: plotly==4.4.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 48)) (4.4.1)
# Requirement already satisfied: psycopg2-binary==2.9.3 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 49)) (2.9.3)
# Requirement already satisfied: pyproj==2.5.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 50)) (2.5.0)
# Requirement already satisfied: PyQt5==5.14.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 51)) (5.14.1)
# Requirement already satisfied: PyQt5-sip==12.11.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 52)) (12.11.0)
# Requirement already satisfied: pyRFC3339==1.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 53)) (1.1)
# Requirement already satisfied: pyrsistent==0.15.5 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 54)) (0.15.5)
# Requirement already satisfied: pytest==4.6.9 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 55)) (4.6.9)
# Requirement already satisfied: python-dateutil==2.8.2 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 56)) (2.8.2)
# Requirement already satisfied: rasterio==1.2.10 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 57)) (1.2.10)
# Requirement already satisfied: requests==2.27.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 58)) (2.27.1)
# Requirement already satisfied: requests-oauthlib==1.3.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 59)) (1.3.1)
# Requirement already satisfied: requests-unixsocket==0.2.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 60)) (0.2.0)
# Requirement already satisfied: retrying==1.3.3 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 61)) (1.3.3)
# Requirement already satisfied: rsa==4.8 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 62)) (4.8)
# Requirement already satisfied: scikit-image==0.16.2 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 63)) (0.16.2)
# Requirement already satisfied: scikit-learn==1.0.2 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 64)) (1.0.2)
# Requirement already satisfied: scipy==1.4.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 65)) (1.4.1)
# Requirement already satisfied: Shapely==1.8.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 66)) (1.8.0)
# Requirement already satisfied: simplejson==3.16.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 67)) (3.16.0)
# Requirement already satisfied: six==1.15.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 68)) (1.15.0)
# Requirement already satisfied: tensorboard==2.2.2 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 69)) (2.2.2)
# Requirement already satisfied: tensorboard-data-server==0.6.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 70)) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit==1.8.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 71)) (1.8.1)
# Requirement already satisfied: tensorflow==2.2.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 72)) (2.2.0)
# Requirement already satisfied: tensorflow-estimator==2.2.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 73)) (2.2.0)
# Requirement already satisfied: torch==1.10.2 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 74)) (1.10.2)
# Requirement already satisfied: torchvision==0.11.3 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 75)) (0.11.3)
# Requirement already satisfied: tornado==6.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 76)) (6.1)
# Requirement already satisfied: tqdm==4.62.3 in /usr/local/lib/python3.8/dist-packages (from -r requirements/colab_requirements.txt (line 77)) (4.62.3)
# Requirement already satisfied: soupsieve>=1.2 in /usr/local/lib/python3.8/dist-packages (from beautifulsoup4==4.8.2->-r requirements/colab_requirements.txt (line 1)) (2.3.2.post1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.8/dist-packages (from black==22.1.0->-r requirements/colab_requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.8/dist-packages (from black==22.1.0->-r requirements/colab_requirements.txt (line 2)) (2.5.4)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /usr/local/lib/python3.8/dist-packages (from black==22.1.0->-r requirements/colab_requirements.txt (line 2)) (4.4.0)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from black==22.1.0->-r requirements/colab_requirements.txt (line 2)) (0.10.3)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from black==22.1.0->-r requirements/colab_requirements.txt (line 2)) (2.0.1)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.8/dist-packages (from black==22.1.0->-r requirements/colab_requirements.txt (line 2)) (8.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from Fiona==1.8.21->-r requirements/colab_requirements.txt (line 5)) (57.4.0)
# Requirement already satisfied: munch in /usr/local/lib/python3.8/dist-packages (from Fiona==1.8.21->-r requirements/colab_requirements.txt (line 5)) (2.5.0)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.8/dist-packages (from Fiona==1.8.21->-r requirements/colab_requirements.txt (line 5)) (22.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from Fiona==1.8.21->-r requirements/colab_requirements.txt (line 5)) (2022.9.24)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.8/dist-packages (from Fiona==1.8.21->-r requirements/colab_requirements.txt (line 5)) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.8/dist-packages (from Fiona==1.8.21->-r requirements/colab_requirements.txt (line 5)) (0.7.2)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from html5lib==1.0.1->-r requirements/colab_requirements.txt (line 13)) (0.5.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata==4.10.1->-r requirements/colab_requirements.txt (line 17)) (3.11.0)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.8/dist-packages (from ipykernel==6.9.0->-r requirements/colab_requirements.txt (line 19)) (8.7.0)
# Requirement already satisfied: traitlets<6.0,>=5.1.0 in /usr/local/lib/python3.8/dist-packages (from ipykernel==6.9.0->-r requirements/colab_requirements.txt (line 19)) (5.6.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from ipykernel==6.9.0->-r requirements/colab_requirements.txt (line 19)) (1.0.0)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.8/dist-packages (from ipykernel==6.9.0->-r requirements/colab_requirements.txt (line 19)) (1.5.6)
# Requirement already satisfied: qtconsole in /usr/local/lib/python3.8/dist-packages (from jupyter==1.0.0->-r requirements/colab_requirements.txt (line 23)) (5.4.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.8/dist-packages (from jupyter==1.0.0->-r requirements/colab_requirements.txt (line 23)) (5.6.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.8/dist-packages (from jupyter==1.0.0->-r requirements/colab_requirements.txt (line 23)) (7.7.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.8/dist-packages (from jupyter-client==7.1.2->-r requirements/colab_requirements.txt (line 24)) (0.4)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.8/dist-packages (from jupyter-client==7.1.2->-r requirements/colab_requirements.txt (line 24)) (23.2.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from jupyter-console==6.4.0->-r requirements/colab_requirements.txt (line 25)) (2.6.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from jupyter-console==6.4.0->-r requirements/colab_requirements.txt (line 25)) (3.0.36)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from Keras==2.3.1->-r requirements/colab_requirements.txt (line 29)) (6.0)
# Requirement already satisfied: PyNaCl<2.0,>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from macaroonbakery==1.3.1->-r requirements/colab_requirements.txt (line 32)) (1.5.0)
# Requirement already satisfied: pymacaroons<1.0,>=0.12.0 in /usr/local/lib/python3.8/dist-packages (from macaroonbakery==1.3.1->-r requirements/colab_requirements.txt (line 32)) (0.13.0)
# Requirement already satisfied: protobuf<4.0,>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from macaroonbakery==1.3.1->-r requirements/colab_requirements.txt (line 32)) (3.19.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib==3.5.1->-r requirements/colab_requirements.txt (line 35)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib==3.5.1->-r requirements/colab_requirements.txt (line 35)) (21.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib==3.5.1->-r requirements/colab_requirements.txt (line 35)) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib==3.5.1->-r requirements/colab_requirements.txt (line 35)) (3.0.9)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.8/dist-packages (from notebook==6.4.8->-r requirements/colab_requirements.txt (line 38)) (1.8.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.8/dist-packages (from notebook==6.4.8->-r requirements/colab_requirements.txt (line 38)) (21.3.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.8/dist-packages (from notebook==6.4.8->-r requirements/colab_requirements.txt (line 38)) (0.15.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.8/dist-packages (from notebook==6.4.8->-r requirements/colab_requirements.txt (line 38)) (5.7.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.8/dist-packages (from notebook==6.4.8->-r requirements/colab_requirements.txt (line 38)) (0.2.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.8/dist-packages (from notebook==6.4.8->-r requirements/colab_requirements.txt (line 38)) (0.13.3)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /usr/local/lib/python3.8/dist-packages (from numba==0.55.1->-r requirements/colab_requirements.txt (line 39)) (0.38.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas==1.3.5->-r requirements/colab_requirements.txt (line 46)) (2022.6)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.8/dist-packages (from pytest==4.6.9->-r requirements/colab_requirements.txt (line 55)) (1.4.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from pytest==4.6.9->-r requirements/colab_requirements.txt (line 55)) (0.2.5)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from pytest==4.6.9->-r requirements/colab_requirements.txt (line 55)) (9.0.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.8/dist-packages (from pytest==4.6.9->-r requirements/colab_requirements.txt (line 55)) (1.11.0)
# Requirement already satisfied: pluggy<1.0,>=0.12 in /usr/local/lib/python3.8/dist-packages (from pytest==4.6.9->-r requirements/colab_requirements.txt (line 55)) (0.13.1)
# Requirement already satisfied: snuggs>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from rasterio==1.2.10->-r requirements/colab_requirements.txt (line 57)) (1.4.7)
# Requirement already satisfied: affine in /usr/local/lib/python3.8/dist-packages (from rasterio==1.2.10->-r requirements/colab_requirements.txt (line 57)) (2.3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.8/dist-packages (from requests==2.27.1->-r requirements/colab_requirements.txt (line 58)) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests==2.27.1->-r requirements/colab_requirements.txt (line 58)) (1.24.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.8/dist-packages (from rsa==4.8->-r requirements/colab_requirements.txt (line 62)) (0.4.8)
# Requirement already satisfied: PyWavelets>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image==0.16.2->-r requirements/colab_requirements.txt (line 63)) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn==1.0.2->-r requirements/colab_requirements.txt (line 64)) (3.1.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.8/dist-packages (from tensorboard==2.2.2->-r requirements/colab_requirements.txt (line 69)) (1.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.8/dist-packages (from tensorboard==2.2.2->-r requirements/colab_requirements.txt (line 69)) (0.38.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard==2.2.2->-r requirements/colab_requirements.txt (line 69)) (0.4.6)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard==2.2.2->-r requirements/colab_requirements.txt (line 69)) (1.35.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.8/dist-packages (from tensorboard==2.2.2->-r requirements/colab_requirements.txt (line 69)) (1.0.1)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0->-r requirements/colab_requirements.txt (line 72)) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0->-r requirements/colab_requirements.txt (line 72)) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0->-r requirements/colab_requirements.txt (line 72)) (2.1.1)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0->-r requirements/colab_requirements.txt (line 72)) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0->-r requirements/colab_requirements.txt (line 72)) (1.14.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<2,>=1.6.3->tensorboard==2.2.2->-r requirements/colab_requirements.txt (line 69)) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<2,>=1.6.3->tensorboard==2.2.2->-r requirements/colab_requirements.txt (line 69)) (0.2.8)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.8/dist-packages (from ipython>=7.23.1->ipykernel==6.9.0->-r requirements/colab_requirements.txt (line 19)) (0.6.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython>=7.23.1->ipykernel==6.9.0->-r requirements/colab_requirements.txt (line 19)) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.8/dist-packages (from ipython>=7.23.1->ipykernel==6.9.0->-r requirements/colab_requirements.txt (line 19)) (0.18.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython>=7.23.1->ipykernel==6.9.0->-r requirements/colab_requirements.txt (line 19)) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython>=7.23.1->ipykernel==6.9.0->-r requirements/colab_requirements.txt (line 19)) (4.4.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.8/dist-packages (from ipython>=7.23.1->ipykernel==6.9.0->-r requirements/colab_requirements.txt (line 19)) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel==6.9.0->-r requirements/colab_requirements.txt (line 19)) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel==6.9.0->-r requirements/colab_requirements.txt (line 19)) (0.7.0)
# Requirement already satisfied: cffi>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from PyNaCl<2.0,>=1.1.2->macaroonbakery==1.3.1->-r requirements/colab_requirements.txt (line 32)) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.4.1->PyNaCl<2.0,>=1.1.2->macaroonbakery==1.3.1->-r requirements/colab_requirements.txt (line 32)) (2.21)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.8/dist-packages (from argon2-cffi->notebook==6.4.8->-r requirements/colab_requirements.txt (line 38)) (21.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->jupyter==1.0.0->-r requirements/colab_requirements.txt (line 23)) (3.6.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter==1.0.0->-r requirements/colab_requirements.txt (line 23)) (0.8.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter==1.0.0->-r requirements/colab_requirements.txt (line 23)) (0.7.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter==1.0.0->-r requirements/colab_requirements.txt (line 23)) (0.6.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter==1.0.0->-r requirements/colab_requirements.txt (line 23)) (5.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter==1.0.0->-r requirements/colab_requirements.txt (line 23)) (1.5.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook==6.4.8->-r requirements/colab_requirements.txt (line 38)) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook==6.4.8->-r requirements/colab_requirements.txt (line 38)) (2.16.2)
# Requirement already satisfied: qtpy>=2.0.1 in /usr/local/lib/python3.8/dist-packages (from qtconsole->jupyter==1.0.0->-r requirements/colab_requirements.txt (line 23)) (2.3.0)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from stack-data->ipython>=7.23.1->ipykernel==6.9.0->-r requirements/colab_requirements.txt (line 19)) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.8/dist-packages (from stack-data->ipython>=7.23.1->ipykernel==6.9.0->-r requirements/colab_requirements.txt (line 19)) (2.2.1)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.8/dist-packages (from stack-data->ipython>=7.23.1->ipykernel==6.9.0->-r requirements/colab_requirements.txt (line 19)) (0.2.2)

# %%
# Install the required packages
# !pip install -r requirements/colab_requirements.txt

# %%
# Get the project root directory 
project_path = PROJECT_ROOT
RCNN_ROOT = os.path.abspath(project_path + "Mask_RCNN")
os.chdir(RCNN_ROOT)
print("Printing the current project root dir".format(os.getcwd()))
# Out:
# Printing the current project root dir

# %%
# Make sure you have these versions: Tensorflow: 2.2.0 and Keras: 2.3.0
print(tf. __version__)
print(tf.keras. __version__)

# and after you will have to restart the runtime to be able to use these versions
# otherwise you will get errors with the latest versions of the above packages
# Out:
# 2.2.0
# 2.3.0-tf

# %%
print(os.getcwd())
# Out:
# /content/drive/My Drive/PROJECTS/HABITUS/plot-delineation-workflow-v2/Mask_RCNN

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
print(tf. __version__)
print(tf.keras. __version__)
# Out:
# 2.2.0
# 2.3.0-tf

# %%
#@title check gpu
# !nvidia-smi
# Out:
# Fri Dec 16 10:56:20 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8    10W /  70W |      3MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
"""
In this section, the required changes to the Mask R-CNN project are discussed so that it fully supports TensorFlow 2.0 
for making predictions (i.e. when the mode parameter in the mrcnn.model.MaskRCNN class constructor is set to inference).
In a later section, more edits are applied to train the Mask R-CNN model in TensorFlow 2.0 (i.e. when the mode parameter
in the mrcnn.model.MaskRCNN class constructor is set to training).

"""

import json
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf


# Set this to True to see more logs details
os.environ["AUTOGRAPH_VERBOSITY"] = "5"
tf.autograph.set_verbosity(3, False)
tf.cast
import warnings

warnings.filterwarnings("ignore")
# from utils.config import CustomConfig


# tf.compat.v1.disable_eager_execution()


# Buiproject_pathld paths inside the project like this: os.path.join(BASE_DIR, ...)
BASE_DIR = '/content/drive/My Drive/PROJECTS/HABITUS/plot-delineation-workflow-v2' #os.path.dirname(os.path.abspath('__file__'))
PROJECT_ROOT = BASE_DIR + "/"
print(PROJECT_ROOT)
# Out:
# /content/drive/My Drive/PROJECTS/HABITUS/plot-delineation-workflow-v2/

# %%
# Get the project root directory 
project_path = PROJECT_ROOT
RCNN_ROOT = os.path.abspath(project_path + "Mask_RCNN")
os.chdir(RCNN_ROOT)
print("Printing the current project root dir".format(os.getcwd()))
# Out:
# Printing the current project root dir

# %%
"""
In this section, the required changes to the Mask R-CNN project are discussed so that it fully supports TensorFlow 2.0 
for making predictions (i.e. when the mode parameter in the mrcnn.model.MaskRCNN class constructor is set to inference).
In a later section, more edits are applied to train the Mask R-CNN model in TensorFlow 2.0 (i.e. when the mode parameter
in the mrcnn.model.MaskRCNN class constructor is set to training).

"""

# %cd  '/content/drive/My Drive/PROJECTS/HABITUS/plot-delineation-workflow-v2'


import json
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf


# Set this to True to see more logs details
os.environ["AUTOGRAPH_VERBOSITY"] = "5"
tf.autograph.set_verbosity(3, False)
tf.cast
import warnings

warnings.filterwarnings("ignore")
from utils.config import CustomConfig

# tf.compat.v1.disable_eager_execution()


# Buiproject_pathld paths inside the project like this: os.path.join(BASE_DIR, ...)
BASE_DIR = '/content/drive/My Drive/PROJECTS/HABITUS/plot-delineation-workflow-v2' #os.path.dirname(os.path.abspath('__file__'))
PROJECT_ROOT = BASE_DIR + "/"
print(PROJECT_ROOT)

# Get the project root directory 
project_path = PROJECT_ROOT
RCNN_ROOT = os.path.abspath(project_path + "Mask_RCNN")
os.chdir(RCNN_ROOT)
print("Printing the current project root dir".format(os.getcwd()))
# Out:
# /content/drive/My Drive/PROJECTS/HABITUS/plot-delineation-workflow-v2
# /content/drive/My Drive/PROJECTS/HABITUS/plot-delineation-workflow-v2/
# /content/drive/My Drive/PROJECTS/HABITUS/plot-delineation-workflow-v2/
# Printing the current project root dir

# %%
# Import Mask RCNN
from Mask_RCNN.mrcnn.config import Config
from Mask_RCNN.mrcnn import utils
import Mask_RCNN.mrcnn.model as modellib
from Mask_RCNN.mrcnn import visualize
from Mask_RCNN.mrcnn.model import log
from PIL import Image, ImageDraw


# Load the TensorBoard notebook extension
# %load_ext tensorboard
import datetime, os

logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)


with open("mrcnn/model.py") as f:
    model_file = f.read()

with open("mrcnn/model.py", "w") as f:
    model_file = model_file.replace(
        "self.keras_model = self.build(mode=mode, config=config)",
        "self.keras_model = self.build(mode=mode, config=config)\n        self.keras_model.metrics_tensors = []",
    )
    f.write(model_file)

"""
Set up logging and pre-trained model paths
This will default to sub-directories in your mask_rcnn_dir, but if you want them somewhere else, updated it here.

It will also download the pre-trained coco model.
"""
# Directory to save logs and trained model while training for backup
DEFAULT_LOGS_DIR = os.path.join(RCNN_ROOT, "logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(RCNN_ROOT, "mask_rcnn_coco.h5")
# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)

##########################################################################################################################
#                     configurations                                                                                     #
##########################################################################################################################

# Set configurations depending on the machine capacity you are using.


class CustomDataset(utils.Dataset):
    """Generates a COCO-like dataset, i.e. an image dataset annotated in the style of the COCO dataset.
    See http://cocodataset.org/#home for more information.
    """

    def load_custom_train(self, annotation_json, images_dir, dataset_type="train"):
        """Load the coco-like dataset from json
        Args:
            annotation_json: The path to the coco annotations json file
            images_dir: The directory holding the images referred to by the json file
        """

        # Load json from file
        print("Annotation json path for train.: ", annotation_json)
        json_file = open(annotation_json)
        coco_json = json.load(json_file)
        json_file.close()

        # Add the class names using the base method from utils.Dataset
        source_name = "coco_like"
        for category in coco_json["categories"]:
            class_id = category["id"]

            class_name = category["name"]
            if class_id < 1:
                print(
                    'Error: Class id for "{}" cannot be less than one. (0 is reserved for the background)'.format(
                        class_name
                    )
                )
                return

            self.add_class(source_name, class_id, class_name)

        # Get all annotations
        annotations = {}
        
        # annotations= []
        for annotation in coco_json["annotations"]:
            annotation["category_id"] = 1
            image_id = annotation["image_id"]
            if image_id not in annotations:
                annotations[image_id] = []
            annotations[image_id].append(annotation)

        # Get all images and add them to the dataset
        seen_images = {}

        # Split the dataset, if train, get 90%, else 10%
        len_images = len(coco_json["images"])
        if dataset_type == "train":
            img_range = [int(len_images / 9), len_images]
        else:
            img_range = [0, int(len_images / 9)]

        for i in range(img_range[0], img_range[1]):
            image = coco_json["images"][i]
            image_id = image["id"]
            if image_id in seen_images:
                print("Warning: Skipping duplicate image id: {}".format(image))
            else:
                seen_images[image_id] = image
                try:
                    image_file_name = image["file_name"]
                    image_width = image["width"]
                    image_height = image["height"]
                except KeyError as key:
                    print(
                        "Warning: Skipping image (id: {}) with missing key: {}".format(
                            image_id, key
                        )
                    )

                image_path = os.path.abspath(os.path.join(images_dir, image_file_name))
                image_annotations = annotations[image_id]
                # Add the image using the base method from utils.Dataset
                self.add_image(
                    source=source_name,
                    image_id=image_id,
                    path=image_path,
                    width=image_width,
                    height=image_height,
                    annotations=image_annotations,
                )

    def load_custom_val(self, annotation_json, images_dir, dataset_type="val"):
        """Load the coco-like dataset from json
        Args:
            annotation_json: The path to the train annotations json file in coco format
            images_dir: The directory holding the images referred to by the json file
        """

        # Load json from file
        print("Annotation json path for val.: ", annotation_json)
        json_file = open(annotation_json)
        coco_json = json.load(json_file)
        json_file.close()

        # Add the class names using the base method from utils.Dataset
        source_name = "coco_like"
        for category in coco_json["categories"]:
            class_id = category["id"]

            class_name = category["name"]
            if class_id < 1:
                print(
                    'Error: Class id for "{}" cannot be less than one. (0 is reserved for the background)'.format(
                        class_name
                    )
                )
                return

            self.add_class(source_name, class_id, class_name)

        # Get all annotations
        annotations = {}
        # annotations= []
        for annotation in coco_json["annotations"]:
            annotation["category_id"] = 1
            image_id = annotation["image_id"]
            if image_id not in annotations:
                annotations[image_id] = []
            annotations[image_id].append(annotation)

        # Get all images and add them to the dataset
        seen_images = {}

        # Split the dataset, if train, get 90%, else 10%
        len_images = len(coco_json["images"])
        if dataset_type == "val":
            img_range = [int(len_images / 9), len_images]
        else:
            img_range = [0, int(len_images / 9)]

        for i in range(img_range[0], img_range[1]):
            image = coco_json["images"][i]
            image_id = image["id"]
            if image_id in seen_images:
                print("Warning: Skipping duplicate image id: {}".format(image))
            else:
                seen_images[image_id] = image
                try:
                    image_file_name = image["file_name"]
                    image_width = image["width"]
                    image_height = image["height"]
                except KeyError as key:
                    print(
                        "Warning: Skipping image (id: {}) with missing key: {}".format(
                            image_id, key
                        )
                    )

                image_path = os.path.abspath(os.path.join(images_dir, image_file_name))
                image_annotations = annotations[image_id]
                # Add the image using the base method from utils.Dataset
                self.add_image(
                    source=source_name,
                    image_id=image_id,
                    path=image_path,
                    width=image_width,
                    height=image_height,
                    annotations=image_annotations,
                )

    def load_mask(self, image_id):
        """Load instance masks for the given image.
        MaskRCNN expects masks in the form of a bitmap [height, width, instances].
        Args:
            image_id: The id of the image to load masks for
        Returns:
            masks: A bool array of shape [height, width, instance count] with
                one mask per instance.
            class_ids: a 1D array of class IDs of the instance masks.
        """
        image_info = self.image_info[image_id]
        print(image_info)
        annotations = image_info["annotations"]
        instance_masks = []
        class_ids = []

        for annotation in annotations:
            class_id = annotation["category_id"]
            mask = Image.new("1", (image_info["width"], image_info["height"]))
            mask_draw = ImageDraw.ImageDraw(mask, "1")
            for segmentation in annotation["segmentation"]:
                mask_draw.polygon(segmentation, fill=1)
                bool_array = np.array(mask) > 0
                instance_masks.append(bool_array)
                class_ids.append(class_id)

        mask = np.dstack(instance_masks)
        class_ids = np.array(class_ids, dtype=np.int32)
        # print("Class_ids, ", class_ids)
        return mask, class_ids

    def count_classes(self):
        class_ids = set()
        for image_id in self.image_ids:
            image_info = self.image_info[image_id]
            annotations = image_info["annotations"]

            for annotation in annotations:
                class_id = annotation["category_id"]
                class_ids.add(class_id)

        class_number = len(class_ids)
        return class_number


##########################################################################################################################
#                 creating the model for plot delineation                                                                               #
##########################################################################################################################

# Visualize the data created


def display_image_samples(dataset_train):
    # Load and display random samples
    image_ids = np.random.choice(2, 4)
    print(dataset_train.image_ids)
    for image_id in image_ids:
        print(image_id)
        image = dataset_train.load_image(image_id)
        mask, class_ids = dataset_train.load_mask(image_id)
        visualize.display_top_masks(image, mask, class_ids, dataset_train.class_names)


# Load the pre-trained model
def load_training_model(config):
    model = modellib.MaskRCNN(
        mode="training", config=config, model_dir=DEFAULT_LOGS_DIR
    )
    print(model)
    # Which weights to start with?
    init_with = "coco"  # imagenet, coco, or last

    if init_with == "imagenet":
        model.load_weights(model.get_imagenet_weights(), by_name=True)
    elif init_with == "coco":
        print('coco')
        # Load weights trained on MS COCO, but skip layers that
        # are different due to the different number of classes
        # See README for instructions to download the COCO weights
        print(COCO_MODEL_PATH)
        model.load_weights(
            COCO_MODEL_PATH,
            by_name=True,
            exclude=["mrcnn_class_logits", "mrcnn_bbox_fc", "mrcnn_bbox", "mrcnn_mask", "rpn_model"],
        )
    elif init_with == "last":
        # Load the last model you trained and continue training
        model.load_weights(model.find_last(), by_name=True)

    return model


# load taining image data
def load_image_dataset_train(annotation_path, dataset_path, dataset_type):
    dataset_train = CustomDataset()
    dataset_train.load_custom_train(annotation_path, dataset_path, dataset_type)
    dataset_train.prepare()
    return dataset_train


# load validation image data
def load_image_dataset_val(annotation_path, dataset_path, dataset_type):
    dataset_val = CustomDataset()
    dataset_val.load_custom_val(annotation_path, dataset_path, dataset_type)
    dataset_val.prepare()
    return dataset_val


"""
Train the model  in two stages:

1. Only the heads. Freeze all the backbone layers and training only the randomly initialized layers 
(i.e. the ones that we didn't use pre-trained weights from MS COCO). To train only the head layers, 
 pass layers='heads' to the train() function.

2. Fine-tune all layers. Simply pass layers="all to train all layers.

TODO: Update the parameters.
"""
# Train the head branches
# Passing layers="heads" freezes all layers except the head


def train_head(
    model, dataset_train, dataset_val, config, epochs
):  # Removed the model and added epochs parameter
    model.train(
        dataset_train,
        dataset_val,
        learning_rate=config.LEARNING_RATE,
        epochs=epochs,
        layers="heads",
        # custom_callbacks=[tensorboard_callback]
    )


# train all layers
def train_all_layers(
    model, dataset_train, dataset_val, config, epochs
):  # Removed the model and added epochs parameter
    model.train(
        dataset_train,
        dataset_val,
        learning_rate=config.LEARNING_RATE / 10,
        epochs=epochs,
        layers="all",
        custom_callbacks=[tensorboard_callback]
    )

# %tensorboard --logdir logs

#######################################################################################################################
#                                        Model training                                                               #
#######################################################################################################################

# Define the data paths

path_dataset = PROJECT_ROOT + "dataset/train"
annotations_path_train = PROJECT_ROOT + "dataset/annotations.json"
annotations_path_val = PROJECT_ROOT + "dataset/annotations.json"
dataset_train = load_image_dataset_train(annotations_path_train, path_dataset, "train")
dataset_val = load_image_dataset_val(annotations_path_val, path_dataset, "val")
class_number = dataset_train.count_classes()

print("Train: %d" % len(dataset_train.image_ids))
print("Validation: %d" % len(dataset_val.image_ids))
print("Classes: {}".format(class_number))

# Load Configuration
# train both the head and layers
class_number = 1
config = CustomConfig(class_number)
config.display()
model = load_training_model(config)


# The model will be saved after every epoch
train_head(model, dataset_train, dataset_val, config, epochs=15)
train_all_layers(model, dataset_train, dataset_val, config, epochs=15)
# Out:
# Using TensorFlow backend.
# 2022-12-16 10:56:21.617255: I tensorflow/core/profiler/lib/profiler_session.cc:159] Profiler session started.
# 2022-12-16 10:56:21.618192: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-12-16 10:56:21.626749: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1363] Profiler found 1 GPUs
# 2022-12-16 10:56:21.626899: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcupti.so.10.1'; dlerror: libcupti.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-12-16 10:56:21.626922: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1408] function cupti_interface_->Subscribe( &subscriber_, (CUpti_CallbackFunc)ApiCallback, this)failed with error CUPTI could not be loaded or symbol could not be found.
# 2022-12-16 10:56:21.626934: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1447] function cupti_interface_->ActivityRegisterCallbacks( AllocCuptiActivityBuffer, FreeCuptiActivityBuffer)failed with error CUPTI could not be loaded or symbol could not be found.
# 2022-12-16 10:56:21.627349: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1430] function cupti_interface_->EnableCallback( 0 , subscriber_, CUPTI_CB_DOMAIN_DRIVER_API, cbid)failed with error CUPTI could not be loaded or symbol could not be found.
# Annotation json path for train.:  /content/drive/My Drive/PROJECTS/HABITUS/plot-delineation-workflow-v2/dataset/annotations.json
# Annotation json path for val.:  /content/drive/My Drive/PROJECTS/HABITUS/plot-delineation-workflow-v2/dataset/annotations.json
# Train: 109
# Validation: 109
# Classes: 1
#
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.9
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  1024
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           object
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                30
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               15
# WEIGHT_DECAY                   0.0001
# 2022-12-16 10:56:21.718708: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-16 10:56:21.719867: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2022-12-16 10:56:21.720154: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-12-16 10:56:21.720319: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcublas.so.10'; dlerror: libcublas.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-12-16 10:56:21.722948: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2022